# %% [markdown]
# ### This is a very early version of the project
#
# let's try importing the data first, and combine them to one big dataframe
#
# after that, build a model with the time variable init.

# %%
import pandas as pd
df = pd.read_csv("../ECGdata/MV/venarh1.txt", sep=r"\s+", skiprows=1)
print(df.head())
# Out:
#    (sec)   (mV)  (mV).1
# 0  0.000 -0.640  -0.070
# 1  0.004 -0.910  -0.065
# 2  0.008 -0.935  -0.060
# 3  0.012 -0.930  -0.035
# 4  0.016 -0.935  -0.040
